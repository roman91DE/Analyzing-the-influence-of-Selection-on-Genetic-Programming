# %%
from scipy.stats import mannwhitneyu, normaltest
import pandas as pd
import numpy as np
from math import sqrt
from matplotlib import pyplot as plt
from typing import Tuple, List
from statistics import mean
import os

# %matplotlib inline
# %cd ~/github/geneticProgramming/seminar/src
# Out:
# /Users/rmn/github/geneticProgramming/seminar/src

# %%
# save all results to PATH (=rmd project folder)

PATH = "../docs/rmd/"
TABLE_PATH = f"{PATH}/tables"
PLOT_PATH =  f"{PATH}/plots"

jobs = (
    'os.makedirs(f"{TABLE_PATH}/csv")',
    'os.makedirs(f"{TABLE_PATH}/md")',
    'os.makedirs(f"{PLOT_PATH}")'
)

for job in jobs:
    try:
        exec(job)
    except FileExistsError:
        pass

# %%
def tsv_to_df(algorithm: str, id: int) -> pd.DataFrame:
    """Return the results for ../results/single_run/<algorithm><id>.tsv as a pd.DataFrame"""
    
    path = f"../results/single_run/{algorithm}/{id}.tsv"
    
    df = pd.read_csv(filepath_or_buffer=path, sep="\t", index_col=False, skipinitialspace=True)
    
    df.columns = df.columns.str.strip()
    
    rename_dict = {
        "avg" : "mean_training_se",
        "std" : "std_training_se",
        "min" : "min_training_se",
        "max" : "max_training_se",
    }
        
    return df.rename(columns=rename_dict) 


# read and store all log files into dataframes
tournament_logs = []
elexicase_logs = []

for n in range(1,101):
    tournament_logs.append(
        tsv_to_df("tournament", n)
    )
    elexicase_logs.append(
        tsv_to_df("e_lexicase", n)
    )

# %%
# print all individual logs

for idx, (a, b) in enumerate(zip(tournament_logs, elexicase_logs)):
    print(f"{idx+1}.th Run:\nTournament-Selection:\n{a.head()}\nE-Lexicase-Selection:\n{b.head()}\n--------------\n")
# Out:
# 1.th Run:
# Tournament-Selection:
#    gen  nevals  mean_training_se  std_training_se  min_training_se  \
# 0    0     500       937393000.0     1.978350e+10          40.8756
# 1    1     113          101204.0     1.347520e+06          40.8756
# 2    2     105       436909000.0     9.758550e+09          40.8756
# 3    3     118           72054.7     7.129410e+05          40.8756
# 4    4     108       437002000.0     9.759480e+09          40.8756
#
#    max_training_se  elite_testing_mse  elite_testing_err_std
# 0     4.425280e+11                NaN                    NaN
# 1     2.422550e+07             32.796                42.3609
# 2     2.184260e+11             32.796                42.3609
# 3     1.118210e+07             32.796                42.3609
# 4     2.184470e+11             32.796                42.3609
# E-Lexicase-Selection:
#    gen  nevals  mean_training_se  std_training_se  min_training_se  \
# 0    0     500       888982000.0     1.733020e+10          73.7153
# 1    1     122          373661.0     4.020160e+06          69.7381
# 2    2     155           73099.1     1.274980e+06          69.7381
# 3    3      99       436966000.0     9.759620e+09          69.7381
# 4    4     125           12524.4     1.567430e+05          69.7381
#
#    max_training_se  elite_testing_mse  elite_testing_err_std
# 0     3.850340e+11                NaN                    NaN
# 1     8.378680e+07            55.8154                86.8526
# 2     2.787660e+07            55.8154                86.8526
# 3     2.184500e+11            55.8154                86.8526
# 4     3.245360e+06            55.8154                86.8526
# --------------
#
# 2.th Run:
# Tournament-Selection:
#    gen  nevals  mean_training_se  std_training_se  min_training_se  \
# 0    0     500       714204000.0     1.060050e+10          105.381
# 1    1     135           17020.3     2.968040e+05          105.381
# 2    2     117          107381.0     1.681960e+06          105.381
# 3    3     110          177583.0     2.228620e+06          105.381
# 4    4     120        37018800.0     7.624830e+08          100.563
#
#    max_training_se  elite_testing_mse  elite_testing_err_std
# 0     2.248260e+11                NaN                    NaN
# 1     6.611810e+06            99.0944                111.544
# 2     3.695970e+07            99.0944                111.544
# 3     3.487030e+07            99.0944                111.544
# 4     1.703510e+10            94.8339                103.192
# E-Lexicase-Selection:
#    gen  nevals  mean_training_se  std_training_se  min_training_se  \
# 0    0     500      9.769370e+15     2.182310e+17         115.3980
# 1    1     121      4.884290e+02     4.695110e+03          84.0678
# 2    2     129      3.029010e+04     3.399660e+05          84.0678
# 3    3     129      5.492030e+04     6.382110e+05          84.0678
# 4    4     137      5.260520e+04     6.215850e+05          84.0678
#
#    max_training_se  elite_testing_mse  elite_testing_err_std
# 0     4.884690e+18                NaN                    NaN
# 1     8.885920e+04            82.9637                141.998
# 2     5.932380e+06            82.9637                141.998
# 3     1.196140e+07            82.9637                141.998
# 4     1.196140e+07            82.9637                141.998
# --------------
#
# 3.th Run:
# Tournament-Selection:
#    gen  nevals  mean_training_se  std_training_se  min_training_se  \
# 0    0     500       813576000.0     1.471180e+10         102.5080
# 1    1     128            6886.0     6.160010e+04         102.5080
# 2    2     132           27457.0     4.201380e+05          96.6360
# 3    3     101           18928.1     2.370110e+05          96.6360
# 4    4     122           42915.5     5.580780e+05          85.4047
#
#    max_training_se  elite_testing_mse  elite_testing_err_std
# 0     3.264400e+11                NaN                    NaN
# 1     1.044490e+06           109.2520                124.030
# 2     9.258850e+06           101.5980                107.879
# 3     5.134530e+06           101.5980                107.879
# 4     1.168270e+07            97.3295                132.836
# E-Lexicase-Selection:
#    gen  nevals  mean_training_se  std_training_se  min_training_se  \
# 0    0     500       249438000.0     2.650880e+09          26.5290
# 1    1     137           79837.6     9.012730e+05          21.2202
# 2    2     151           54119.1     5.457130e+05          21.2202
# 3    3     131         2558600.0     5.559450e+07          21.0961
# 4    4     136          394158.0     7.831250e+06          21.0362
#
#    max_training_se  elite_testing_mse  elite_testing_err_std
# 0     4.801100e+10                NaN                    NaN
# 1     1.528930e+07            24.1128                35.4313
# 2     1.168270e+07            24.1128                35.4313
# 3     1.244360e+09            23.8803                35.4016
# 4     1.750870e+08            23.8292                35.4985
# --------------
#
# 4.th Run:
# Tournament-Selection:
#    gen  nevals  mean_training_se  std_training_se  min_training_se  \
# 0    0     500      1.387020e+09     2.082470e+10          60.1066
# 1    1     124      7.463810e+04     8.829090e+05          26.6697
# 2    2     117      1.100480e+05     1.258790e+06          78.7857
# 3    3     131      2.205850e+04     2.390090e+05          49.7655
# 4    4     135      6.833560e+05     1.420260e+07          49.7655
#
#    max_training_se  elite_testing_mse  elite_testing_err_std
# 0     4.049120e+11                NaN                    NaN
# 1     1.761850e+07            26.9838                 44.274
# 2     1.761850e+07            26.9838                 44.274
# 3     3.985740e+06            26.9838                 44.274
# 4     3.178450e+08            26.9838                 44.274
# E-Lexicase-Selection:
#    gen  nevals  mean_training_se  std_training_se  min_training_se  \
# 0    0     500       948909000.0     2.030800e+10          36.0154
# 1    1     127           27546.9     4.471740e+05          36.0154
# 2    2     137           32748.3     5.659890e+05          36.0154
# 3    3     132          623009.0     1.288410e+07          36.0154
# 4    4     110           12981.6     2.309420e+05          36.0154
#
#    max_training_se  elite_testing_mse  elite_testing_err_std
# 0     4.542780e+11                NaN                    NaN
# 1     9.774830e+06            37.6562                56.7025
# 2     1.221360e+07            37.6562                56.7025
# 3     2.877760e+08            37.6562                56.7025
# 4     4.988670e+06            37.6562                56.7025
# --------------
#
# 5.th Run:
# Tournament-Selection:
#    gen  nevals  mean_training_se  std_training_se  min_training_se  \
# 0    0     500       133540000.0     2.229610e+09         117.4470
# 1    1      97           19420.0     2.807950e+05         117.4470
# 2    2     109           40650.0     7.854280e+05          89.2752
# 3    3     106           82562.8     8.913570e+05          89.2752
# 4    4     117           10020.3     8.020430e+04          89.2752
#
#    max_training_se  elite_testing_mse  elite_testing_err_std
# 0     4.706740e+10                NaN                    NaN
# 1     6.070040e+06           106.7100                134.189
# 2     1.752240e+07            77.7562                136.399
# 3     1.752240e+07            77.7562                136.399
# 4     1.343180e+06            77.7562                136.399
# E-Lexicase-Selection:
#    gen  nevals  mean_training_se  std_training_se  min_training_se  \
# 0    0     500      1.248870e+09     1.771950e+10         117.1860
# 1    1      96      9.512080e+03     6.009680e+04         116.5500
# 2    2     120      2.583740e+03     1.492140e+04          95.6056
# 3    3     141      1.082790e+05     9.655070e+05          95.6056
# 4    4     121      2.291380e+04     3.978850e+05          95.1783
#
#    max_training_se  elite_testing_mse  elite_testing_err_std
# 0     3.269900e+11                NaN                    NaN
# 1     4.838090e+05           105.9480               132.6700
# 2     1.065490e+05            90.0688                83.7075
# 3     8.868420e+06            90.0688                83.7075
# 4     8.868420e+06            93.2190                68.4165
# --------------
#
# 6.th Run:
# Tournament-Selection:
#    gen  nevals  mean_training_se  std_training_se  min_training_se  \
# 0    0     500      2.497160e+09     3.417650e+10          82.4842
# 1    1     135      8.635070e+04     1.006240e+06          82.4842
# 2    2     125      1.689430e+05     1.525480e+06          82.4842
# 3    3     110      8.599940e+04     8.241490e+05          36.6224
# 4    4      96      9.094010e+05     1.467990e+07          36.6224
#
#    max_training_se  elite_testing_mse  elite_testing_err_std
# 0     6.919410e+11                NaN                    NaN
# 1     1.770830e+07            81.0765               127.2300
# 2     1.770830e+07            81.0765               127.2300
# 3     1.209750e+07            37.0492                52.8943
# 4     3.199300e+08            37.0492                52.8943
# E-Lexicase-Selection:
#    gen  nevals  mean_training_se  std_training_se  min_training_se  \
# 0    0     500       393396000.0     3.975650e+09          84.1146
# 1    1     117           44207.9     3.288580e+05          84.1146
# 2    2     120          364362.0     7.600570e+06          64.7028
# 3    3     127          132500.0     1.344320e+06          64.7028
# 4    4     115           54675.6     7.029020e+05          63.6298
#
#    max_training_se  elite_testing_mse  elite_testing_err_std
# 0     4.927650e+10                NaN                    NaN
# 1     3.461910e+06            82.9168               129.9420
# 2     1.696940e+08            59.4712                85.1765
# 3     1.946900e+07            59.4712                85.1765
# 4     1.209750e+07            57.0797                83.2285
# --------------
#
# 7.th Run:
# Tournament-Selection:
#    gen  nevals  mean_training_se  std_training_se  min_training_se  \
# 0    0     500       148463000.0     2.261630e+09          77.1167
# 1    1     114        34437900.0     7.692040e+08          43.9292
# 2    2     131           62480.7     6.458740e+05          42.6598
# 3    3     124        34597700.0     7.692000e+08          42.6598
# 4    4     134         6795240.0     1.471950e+08          42.6598
#
#    max_training_se  elite_testing_mse  elite_testing_err_std
# 0     4.739520e+10                NaN                    NaN
# 1     1.721720e+10            42.6669                47.0827
# 2     1.168530e+07            42.0917                54.5885
# 3     1.721720e+10            42.0917                54.5885
# 4     3.294640e+09            42.0917                54.5885
# E-Lexicase-Selection:
#    gen  nevals  mean_training_se  std_training_se  min_training_se  \
# 0    0     500       555419000.0     1.016280e+10          77.1167
# 1    1     115          171583.0     1.109880e+06          77.1167
# 2    2      97           60407.8     3.905600e+05          41.4788
# 3    3      94        48575300.0     1.023330e+09          41.4788
# 4    4     114           57229.1     5.454700e+05          41.4788
#
#    max_training_se  elite_testing_mse  elite_testing_err_std
# 0     2.254480e+11                NaN                    NaN
# 1     1.168530e+07            89.9147               144.3930
# 2     3.104910e+06            40.3840                46.3354
# 3     2.286530e+10            40.3840                46.3354
# 4     1.168530e+07            40.3840                46.3354
# --------------
#
# 8.th Run:
# Tournament-Selection:
#    gen  nevals  mean_training_se  std_training_se  min_training_se  \
# 0    0     500      2.892760e+08     2.823820e+09          86.2756
# 1    1     105      8.228140e+03     7.096430e+04          86.2756
# 2    2     131      5.963620e+04     7.887500e+05          86.2756
# 3    3     104      3.554340e+03     3.644240e+04          86.2756
# 4    4     126      5.727170e+04     5.815050e+05          86.2756
#
#    max_training_se  elite_testing_mse  elite_testing_err_std
# 0     4.888780e+10                NaN                    NaN
# 1     1.128230e+06            80.7559                124.501
# 2     1.257580e+07            80.7559                124.501
# 3     5.229750e+05            80.7559                124.501
# 4     1.004030e+07            80.7559                124.501
# E-Lexicase-Selection:
#    gen  nevals  mean_training_se  std_training_se  min_training_se  \
# 0    0     500      1.589220e+08     2.346580e+09          33.8478
# 1    1     106      4.071430e+03     6.871510e+04          33.8478
# 2    2     111      1.425870e+04     2.963570e+05          33.8478
# 3    3     120      1.539610e+06     3.428480e+07          33.8478
# 4    4     132      3.154140e+07     7.042550e+08          26.9948
#
#    max_training_se  elite_testing_mse  elite_testing_err_std
# 0     4.840300e+10                NaN                    NaN
# 1     1.456200e+06            30.5953                52.5226
# 2     6.620670e+06            30.5953                52.5226
# 3     7.674020e+08            30.5953                52.5226
# 4     1.576340e+10            25.9265                38.3916
# --------------
#
# 9.th Run:
# Tournament-Selection:
#    gen  nevals  mean_training_se  std_training_se  min_training_se  \
# 0    0     500       668506000.0     7.280210e+09          82.1050
# 1    1     112          259393.0     5.667490e+06          23.0132
# 2    2     122        53444800.0     1.193260e+09          82.1050
# 3    3      98        97398600.0     2.174450e+09          73.3405
# 4    4     127          204928.0     1.450810e+06          64.8668
#
#    max_training_se  elite_testing_mse  elite_testing_err_std
# 0     1.196410e+11                NaN                    NaN
# 1     1.268570e+08            24.7849                40.0661
# 2     2.670890e+10            24.7849                40.0661
# 3     4.867090e+10            24.7849                40.0661
# 4     1.955710e+07            24.7849                40.0661
# E-Lexicase-Selection:
#    gen  nevals  mean_training_se  std_training_se  min_training_se  \
# 0    0     500        32637000.0     5.379970e+08          69.1301
# 1    1     122           28892.5     5.357290e+05          62.8381
# 2    2     127            2855.7     3.412220e+04          27.7297
# 3    3     127           26742.6     5.554190e+05          20.7775
# 4    4     136       657701000.0     1.466470e+10          20.7775
#
#    max_training_se  elite_testing_mse  elite_testing_err_std
# 0     1.148930e+10                NaN                    NaN
# 1     1.194950e+07            67.2728                62.3924
# 2     4.487240e+05            31.3129                53.2163
# 3     1.241320e+07            22.3499                38.6236
# 4     3.282420e+11            22.3499                38.6236
# --------------
#
# 10.th Run:
# Tournament-Selection:
#    gen  nevals  mean_training_se  std_training_se  min_training_se  \
# 0    0     500      6.686540e+08     1.035130e+10          97.5315
# 1    1     103      2.929270e+07     5.289900e+08          97.5315
# 2    2     126      8.932590e+03     6.303830e+04          82.4581
# 3    3     111      1.169360e+08     2.149710e+09          82.4581
# 4    4     104      1.469270e+08     2.238440e+09          82.4581
#
#    max_training_se  elite_testing_mse  elite_testing_err_std
# 0     2.214190e+11                NaN                    NaN
# 1     1.139250e+10            99.5765                117.140
# 2     8.364270e+05            84.5734                138.217
# 3     4.739190e+10            84.5734                138.217
# 4     4.739190e+10            84.5734                138.217
# E-Lexicase-Selection:
#    gen  nevals  mean_training_se  std_training_se  min_training_se  \
# 0    0     500      1.945290e+09     3.088160e+10          94.0298
# 1    1     121      5.646860e+04     4.666600e+05          92.1825
# 2    2     110      1.440710e+04     2.721460e+05          92.1825
# 3    3     109      4.121100e+03     2.677110e+04          65.0350
# 4    4     115      4.493910e+03     2.006550e+04          65.0350
#
#    max_training_se  elite_testing_mse  elite_testing_err_std
# 0     6.536590e+11                NaN                    NaN
# 1     4.644220e+06            93.0393                70.4410
# 2     6.086470e+06            93.0393                70.4410
# 3     4.511270e+05            65.7641                60.0207
# 4     9.949960e+04            65.7641                60.0207
# --------------
#
# 11.th Run:
# Tournament-Selection:
#    gen  nevals  mean_training_se  std_training_se  min_training_se  \
# 0    0     500       805522000.0     1.054990e+10         105.1980
# 1    1     109           29801.5     5.487670e+05         105.1980
# 2    2     104           19297.8     1.618540e+05          84.0564
# 3    3     107           40189.2     4.151520e+05          84.0564
# 4    4     149           57637.8     4.583470e+05          84.0564
#
#    max_training_se  elite_testing_mse  elite_testing_err_std
# 0     2.196330e+11                NaN                    NaN
# 1     1.225310e+07            107.619                77.8899
# 2     2.984430e+06             82.975               143.1160
# 3     6.052430e+06             82.975               143.1160
# 4     6.052430e+06             82.975               143.1160
# E-Lexicase-Selection:
#    gen  nevals  mean_training_se  std_training_se  min_training_se  \
# 0    0     500      6.108900e+08     1.008580e+10          84.0564
# 1    1     105      4.772330e+04     3.900970e+05          84.0564
# 2    2     119      1.207800e+08     2.095290e+09          27.4248
# 3    3      99      1.356550e+03     2.256810e+04          27.4248
# 4    4     126      5.580550e+03     9.767270e+04          27.4248
#
#    max_training_se  elite_testing_mse  elite_testing_err_std
# 0     2.196710e+11                NaN                    NaN
# 1     3.807560e+06            82.9750                143.116
# 2     4.396350e+10            26.2287                 45.694
# 3     4.954780e+05            26.2287                 45.694
# 4     2.142160e+06            26.2287                 45.694
# --------------
#
# 12.th Run:
# Tournament-Selection:
#    gen  nevals  mean_training_se  std_training_se  min_training_se  \
# 0    0     500      7.978020e+09     1.446340e+11          80.0305
# 1    1     119      2.396190e+03     2.171660e+04          80.0305
# 2    2     138      1.555240e+04     1.651990e+05          80.0305
# 3    3     102      2.130650e+07     4.745480e+08          67.9588
# 4    4     125      3.569450e+04     4.161720e+05          67.9588
#
#    max_training_se  elite_testing_mse  elite_testing_err_std
# 0     3.208890e+12                NaN                    NaN
# 1     4.379920e+05            87.0009                142.140
# 2     3.218740e+06            87.0009                142.140
# 3     1.062190e+10            74.4573                108.677
# 4     8.026540e+06            74.4573                108.677
# E-Lexicase-Selection:
#    gen  nevals  mean_training_se  std_training_se  min_training_se  \
# 0    0     500       352750000.0     4.082830e+09          80.0305
# 1    1     120          322261.0     2.662930e+06          80.0305
# 2    2     125         1715810.0     3.776390e+07          80.0305
# 3    3      98           73948.5     1.151200e+06          77.9583
# 4    4     117          919680.0     1.922520e+07          75.6763
#
#    max_training_se  elite_testing_mse  elite_testing_err_std
# 0     7.254010e+10                NaN                    NaN
# 1     3.762170e+07            87.0009                142.140
# 2     8.452660e+08            87.0009                142.140
# 3     2.476640e+07            83.7049                135.607
# 4     4.300860e+08            81.5161                133.667
# --------------
#
# 13.th Run:
# Tournament-Selection:
#    gen  nevals  mean_training_se  std_training_se  min_training_se  \
# 0    0     500      3.617890e+12     8.080390e+13          99.0326
# 1    1     126      1.242540e+04     1.640690e+05          99.0326
# 2    2      99      1.385000e+04     1.779790e+05          94.2944
# 3    3     133      1.425970e+05     1.501610e+06          68.3066
# 4    4     125      3.565160e+07     7.942870e+08          62.5888
#
#    max_training_se  elite_testing_mse  elite_testing_err_std
# 0     1.808640e+15                NaN                    NaN
# 1     3.466600e+06           125.4030               144.1290
# 2     3.697080e+06            99.3317                74.6671
# 3     2.078050e+07            87.8289               117.7720
# 4     1.777870e+10            61.4943                69.6765
# E-Lexicase-Selection:
#    gen  nevals  mean_training_se  std_training_se  min_training_se  \
# 0    0     500       241808000.0     2.574320e+09          85.7787
# 1    1      92          182051.0     2.014360e+06          85.4944
# 2    2     112          170595.0     3.168990e+06          85.4944
# 3    3     145          596063.0     1.175160e+07          85.4944
# 4    4     122          250239.0     3.564710e+06          85.4944
#
#    max_training_se  elite_testing_mse  elite_testing_err_std
# 0     4.827790e+10                NaN                    NaN
# 1     3.946670e+07            106.131                162.231
# 2     7.068670e+07            106.131                162.231
# 3     2.609200e+08            106.131                162.231
# 4     6.610950e+07            106.131                162.231
# --------------
#
# 14.th Run:
# Tournament-Selection:
#    gen  nevals  mean_training_se  std_training_se  min_training_se  \
# 0    0     500       670496000.0     1.062900e+10          82.5882
# 1    1     131           29020.3     5.333820e+05          82.5882
# 2    2      87         6722120.0     1.501260e+08          82.5882
# 3    3      99          133199.0     1.267470e+06          82.5882
# 4    4     100          232583.0     1.591310e+06          82.5882
#
#    max_training_se  elite_testing_mse  elite_testing_err_std
# 0     2.280060e+11                NaN                    NaN
# 1     1.190250e+07             82.895                119.474
# 2     3.360290e+09             82.895                119.474
# 3     2.094840e+07             82.895                119.474
# 4     2.094840e+07             82.895                119.474
# E-Lexicase-Selection:
#    gen  nevals  mean_training_se  std_training_se  min_training_se  \
# 0    0     500       762409000.0     1.070270e+10          85.7802
# 1    1     124          568818.0     4.145050e+06          84.4253
# 2    2      99          176770.0     1.190180e+06          84.4253
# 3    3     111           43507.0     4.855520e+05          61.3992
# 4    4      88          318576.0     7.103880e+06          54.5955
#
#    max_training_se  elite_testing_mse  elite_testing_err_std
# 0     2.281800e+11                NaN                    NaN
# 1     6.101610e+07            80.9220               111.6360
# 2     1.649940e+07            80.9220               111.6360
# 3     8.173270e+06            61.4594                90.6416
# 4     1.590070e+08            53.3881                84.5242
# --------------
#
# 15.th Run:
# Tournament-Selection:
#    gen  nevals  mean_training_se  std_training_se  min_training_se  \
# 0    0     500      2.598030e+11     5.790750e+12           24.914
# 1    1     113      2.225210e+04     2.952730e+05           24.914
# 2    2     107      6.580920e+06     1.465410e+08           24.914
# 3    3     128      3.970250e+09     8.868240e+10           24.914
# 4    4      94      6.980360e+04     6.456530e+05           24.914
#
#    max_training_se  elite_testing_mse  elite_testing_err_std
# 0     1.296150e+14                NaN                    NaN
# 1     6.056820e+06            28.7395                48.7422
# 2     3.280050e+09            28.7395                48.7422
# 3     1.984990e+12            28.7395                48.7422
# 4     1.021550e+07            28.7395                48.7422
# E-Lexicase-Selection:
#    gen  nevals  mean_training_se  std_training_se  min_training_se  \
# 0    0     500      1.552690e+09     2.269640e+10         110.7480
# 1    1     126      1.042610e+05     9.668280e+05         108.3200
# 2    2     106      5.369460e+03     3.336870e+04          96.1514
# 3    3     113      4.440850e+03     7.012810e+04          96.1514
# 4    4     124      1.099260e+02     6.282940e+01          96.1514
#
#    max_training_se  elite_testing_mse  elite_testing_err_std
# 0     4.540080e+11                NaN                    NaN
# 1     1.208480e+07           109.2290               130.0760
# 2     4.518810e+05            97.9262                73.2721
# 3     1.326000e+06            97.9262                73.2721
# 4     7.680940e+02            97.9262                73.2721
# --------------
#
# 16.th Run:
# Tournament-Selection:
#    gen  nevals  mean_training_se  std_training_se  min_training_se  \
# 0    0     500       605446000.0     1.004050e+10          93.3075
# 1    1     115           11107.7     1.809820e+05          93.3075
# 2    2     140          480630.0     9.602710e+06          85.9874
# 3    3     108           16165.6     1.249370e+05          84.0998
# 4    4     115           18840.0     1.877430e+05          21.4550
#
#    max_training_se  elite_testing_mse  elite_testing_err_std
# 0     2.209860e+11                NaN                    NaN
# 1     4.005650e+06            83.3473               142.1820
# 2     2.145170e+08            77.2042               127.5450
# 3     1.560350e+06            76.3543               127.8050
# 4     3.396250e+06            19.3186                37.2469
# E-Lexicase-Selection:
#    gen  nevals  mean_training_se  std_training_se  min_training_se  \
# 0    0     500      4.745750e+08     5.773780e+09         108.2620
# 1    1     112      1.827790e+05     1.381670e+06         108.2620
# 2    2     139      1.236140e+05     6.416390e+05          94.0178
# 3    3     106      1.552420e+02     5.497220e+02          73.5594
# 4    4     131      4.630590e+02     5.724820e+03          73.3965
#
#    max_training_se  elite_testing_mse  elite_testing_err_std
# 0     1.073750e+11                NaN                    NaN
# 1     1.619850e+07           107.9280               108.6740
# 2     3.708600e+06            99.8254                73.4825
# 3     1.210800e+04            70.6409                71.9852
# 4     9.078790e+04            70.5730                71.3000
# --------------
#
# 17.th Run:
# Tournament-Selection:
#    gen  nevals  mean_training_se  std_training_se  min_training_se  \
# 0    0     500      1.222100e+09     1.873530e+10         115.5100
# 1    1     119      3.145910e+03     2.737130e+04         115.5100
# 2    2     125      4.223680e+04     5.552950e+05         115.5100
# 3    3     134      1.608220e+04     9.939220e+04          83.8419
# 4    4     123      1.132790e+05     2.053760e+06          83.8419
#
#    max_training_se  elite_testing_mse  elite_testing_err_std
# 0     3.566070e+11                NaN                    NaN
# 1     4.266030e+05           108.9260                135.400
# 2     1.123140e+07           108.9260                135.400
# 3     1.348480e+06            83.7036                 89.644
# 4     4.571630e+07            83.7036                 89.644
# E-Lexicase-Selection:
#    gen  nevals  mean_training_se  std_training_se  min_training_se  \
# 0    0     500      3.666390e+09     8.015580e+10          36.5876
# 1    1     129      7.991240e+03     1.480130e+05          36.5876
# 2    2     132      8.965420e+03     1.500180e+05          36.5876
# 3    3     106      2.783370e+03     3.890210e+04          36.5876
# 4    4     103      2.539050e+04     5.064430e+05          36.5876
#
#    max_training_se  elite_testing_mse  elite_testing_err_std
# 0     1.794050e+12                NaN                    NaN
# 1     3.280160e+06            37.0839                  49.63
# 2     3.240170e+06            37.0839                  49.63
# 3     7.824410e+05            37.0839                  49.63
# 4     1.130050e+07            37.0839                  49.63
# --------------
#
# 18.th Run:
# Tournament-Selection:
#    gen  nevals  mean_training_se  std_training_se  min_training_se  \
# 0    0     500      1.381480e+13     3.085730e+14          92.5785
# 1    1     122      3.690260e+04     5.756460e+05          82.8839
# 2    2     125      5.483270e+05     1.181430e+07          82.8839
# 3    3     116      1.119370e+05     1.069310e+06          68.9103
# 4    4     125      4.125980e+05     4.609920e+06          68.9103
#
#    max_training_se  elite_testing_mse  elite_testing_err_std
# 0     6.906800e+15                NaN                    NaN
# 1     1.241310e+07            84.1475                138.894
# 2     2.644040e+08            84.1475                138.894
# 3     1.902010e+07            69.0470                106.365
# 4     5.948040e+07            69.0470                106.365
# E-Lexicase-Selection:
#    gen  nevals  mean_training_se  std_training_se  min_training_se  \
# 0    0     500      6.289660e+09     1.397390e+11          68.9646
# 1    1     147      7.542390e+04     6.647990e+05          68.9646
# 2    2     114      3.605840e+04     6.505070e+05          68.9646
# 3    3     106      2.956620e+04     6.285470e+05          68.9646
# 4    4     136      6.657140e+03     1.398330e+05          68.9646
#
#    max_training_se  elite_testing_mse  elite_testing_err_std
# 0     3.127780e+12                NaN                    NaN
# 1     1.205410e+07            70.7421                84.0535
# 2     1.420760e+07            70.7421                84.0535
# 3     1.406190e+07            70.7421                84.0535
# 4     3.128930e+06            70.7421                84.0535
# --------------
#
# 19.th Run:
# Tournament-Selection:
#    gen  nevals  mean_training_se  std_training_se  min_training_se  \
# 0    0     500      3.932360e+09     7.649230e+10          89.9058
# 1    1     117      1.366800e+04     1.432030e+05          74.4506
# 2    2     123      4.952840e+04     4.658890e+05          74.4506
# 3    3     104      1.878380e+05     2.173330e+06          66.2664
# 4    4     117      1.570220e+05     1.687850e+06          66.2664
#
#    max_training_se  elite_testing_mse  elite_testing_err_std
# 0     1.701640e+12                NaN                    NaN
# 1     2.642590e+06            86.8358                138.197
# 2     6.443100e+06            86.8358                138.197
# 3     3.346350e+07            77.0232                120.793
# 4     3.349240e+07            77.0232                120.793
# E-Lexicase-Selection:
#    gen  nevals  mean_training_se  std_training_se  min_training_se  \
# 0    0     500      6.627460e+08     1.077290e+10          98.2702
# 1    1     116      2.087270e+04     2.918490e+05          73.3133
# 2    2     101      1.275870e+03     1.696820e+04          48.5582
# 3    3     137      5.951110e+04     6.524410e+05          48.5229
# 4    4     132      2.709210e+04     4.323160e+05          41.0968
#
#    max_training_se  elite_testing_mse  elite_testing_err_std
# 0     2.314090e+11                NaN                    NaN
# 1     5.703240e+06            64.1435                57.8955
# 2     3.516380e+05            41.5616                35.7071
# 3     1.164350e+07            41.5423                35.6894
# 4     8.322660e+06            35.5292                67.8006
# --------------
#
# 20.th Run:
# Tournament-Selection:
#    gen  nevals  mean_training_se  std_training_se  min_training_se  \
# 0    0     500      1.034170e+10     2.305680e+11          81.9661
# 1    1     106      4.518650e+08     1.009350e+10          81.9661
# 2    2     124      2.288070e+07     5.093530e+08          81.9661
# 3    3     101      1.419390e+08     2.257690e+09          81.9661
# 4    4     126      1.415520e+08     2.257710e+09          81.9661
#
#    max_training_se  elite_testing_mse  elite_testing_err_std
# 0     5.160840e+12                NaN                    NaN
# 1     2.259240e+11            85.0653                142.912
# 2     1.140100e+10            85.0653                142.912
# 3     4.794450e+10            85.0653                142.912
# 4     4.794450e+10            85.0653                142.912
# E-Lexicase-Selection:
#    gen  nevals  mean_training_se  std_training_se  min_training_se  \
# 0    0     500       266454000.0     3.209360e+09         112.4720
# 1    1     127          169604.0     1.243730e+06          78.9098
# 2    2     105          181066.0     1.295410e+06          56.1972
# 3    3     117         1208070.0     2.581670e+07          41.5164
# 4    4     126           55596.8     8.020070e+05          41.5164
#
#    max_training_se  elite_testing_mse  elite_testing_err_std
# 0     4.804850e+10                NaN                    NaN
# 1     1.205020e+07            77.2257               110.5150
# 2     1.337930e+07            54.6784                88.5608
# 3     5.776720e+08            40.5600                40.1093
# 4     1.696190e+07            40.5600                40.1093
# --------------
#
# 21.th Run:
# Tournament-Selection:
#    gen  nevals  mean_training_se  std_training_se  min_training_se  \
# 0    0     500      3.030180e+12     6.590140e+13          81.3401
# 1    1     124      1.609160e+05     2.648960e+06          81.3401
# 2    2     102      1.304090e+05     1.835850e+06          81.3401
# 3    3     108      1.162430e+05     1.057240e+06          73.9961
# 4    4     116      1.755220e+05     1.273930e+06          73.9961
#
#    max_training_se  elite_testing_mse  elite_testing_err_std
# 0     1.474730e+15                NaN                    NaN
# 1     5.705390e+07            85.6914               143.0000
# 2     3.888310e+07            85.6914               143.0000
# 3     1.196350e+07            69.3585                56.6858
# 4     1.543730e+07            69.3585                56.6858
# E-Lexicase-Selection:
#    gen  nevals  mean_training_se  std_training_se  min_training_se  \
# 0    0     500      1.001230e+08     1.280770e+09          118.614
# 1    1     138      8.084340e+04     8.321490e+05          117.689
# 2    2     134      1.325050e+03     2.006830e+04          117.689
# 3    3     115      2.709100e+02     1.690590e+03          117.689
# 4    4     113      2.173640e+03     2.934450e+04          117.663
#
#    max_training_se  elite_testing_mse  elite_testing_err_std
# 0     2.210250e+10                NaN                    NaN
# 1     1.196190e+07            105.777                 85.266
# 2     4.316600e+05            105.777                 85.266
# 3     2.685980e+04            105.777                 85.266
# 4     4.884770e+05            105.775                 85.161
# --------------
#
# 22.th Run:
# Tournament-Selection:
#    gen  nevals  mean_training_se  std_training_se  min_training_se  \
# 0    0     500      1.895200e+08     2.980660e+09          83.5504
# 1    1      95      2.991570e+04     4.351070e+05          83.5504
# 2    2     138      1.220260e+09     2.725770e+10          73.0310
# 3    3     114      1.009390e+08     2.114440e+09          73.0310
# 4    4     129      6.864500e+07     8.806290e+08          73.0310
#
#    max_training_se  elite_testing_mse  elite_testing_err_std
# 0     4.722330e+10                NaN                    NaN
# 1     9.278540e+06            83.4811                137.111
# 2     6.101110e+11            83.1044                115.434
# 3     4.722330e+10            83.1044                115.434
# 4     1.153170e+10            83.1044                115.434
# E-Lexicase-Selection:
#    gen  nevals  mean_training_se  std_training_se  min_training_se  \
# 0    0     500       190203000.0     2.352630e+09          44.7212
# 1    1     125          120909.0     8.620790e+05          42.1823
# 2    2     129            6352.0     6.127500e+04          24.0766
# 3    3      97           18819.9     2.454250e+05          24.0766
# 4    4     110           51348.4     6.807270e+05          24.0766
#
#    max_training_se  elite_testing_mse  elite_testing_err_std
# 0     4.722760e+10                NaN                    NaN
# 1     1.196990e+07            49.2691                78.5692
# 2     8.848270e+05            29.5769                48.1908
# 3     4.017710e+06            29.5769                48.1908
# 4     1.200810e+07            29.5769                48.1908
# --------------
#
# 23.th Run:
# Tournament-Selection:
#    gen  nevals  mean_training_se  std_training_se  min_training_se  \
# 0    0     500        80791900.0     9.556300e+08          93.2425
# 1    1     124          118767.0     1.210890e+06          93.2425
# 2    2     127        33061900.0     7.351080e+08          93.2425
# 3    3     105       329918000.0     7.369060e+09          93.2425
# 4    4     125           91522.7     7.583870e+05          66.5225
#
#    max_training_se  elite_testing_mse  elite_testing_err_std
# 0     1.647820e+10                NaN                    NaN
# 1     1.830510e+07            73.7889               120.9840
# 2     1.645400e+10            73.7889               120.9840
# 3     1.649420e+11            73.7889               120.9840
# 4     1.227550e+07            64.2767                58.2761
# E-Lexicase-Selection:
#    gen  nevals  mean_training_se  std_training_se  min_training_se  \
# 0    0     500      1.320940e+09     2.943840e+10          98.8873
# 1    1     131      3.447910e+07     7.700490e+08          98.8873
# 2    2     129      1.766630e+04     3.802960e+05          98.8873
# 3    3      95      1.899610e+03     2.697500e+04          91.3225
# 4    4     129      1.708580e+02     2.120890e+02          72.4862
#
#    max_training_se  elite_testing_mse  elite_testing_err_std
# 0     6.589230e+11                NaN                    NaN
# 1     1.723610e+10            90.9265                95.2705
# 2     8.509820e+06            90.9265                95.2705
# 3     4.271550e+05            89.2236                69.0821
# 4     2.965220e+03            69.1876                65.1480
# --------------
#
# 24.th Run:
# Tournament-Selection:
#    gen  nevals  mean_training_se  std_training_se  min_training_se  \
# 0    0     500      1.250420e+08     1.341160e+09          77.8263
# 1    1     103      6.905390e+03     8.406950e+04          77.8263
# 2    2     114      2.340930e+07     5.219420e+08          77.8263
# 3    3     110      7.253540e+04     7.046630e+05          77.8263
# 4    4     115      6.282450e+04     5.332940e+05          63.0238
#
#    max_training_se  elite_testing_mse  elite_testing_err_std
# 0     1.693710e+10                NaN                    NaN
# 1     1.712040e+06            89.2052               142.8390
# 2     1.168270e+10            89.2052               142.8390
# 3     1.191350e+07            89.2052               142.8390
# 4     6.529320e+06            68.8199                66.6856
# E-Lexicase-Selection:
#    gen  nevals  mean_training_se  std_training_se  min_training_se  \
# 0    0     500      1.965550e+08     2.469150e+09         108.1270
# 1    1     130      4.347810e+04     3.699670e+05          90.8545
# 2    2     117      2.780220e+04     2.301810e+05          89.7719
# 3    3     117      5.719570e+03     2.830390e+04          89.6209
# 4    4     118      2.194310e+04     2.797900e+05          83.3393
#
#    max_training_se  elite_testing_mse  elite_testing_err_std
# 0     4.848180e+10                NaN                    NaN
# 1     6.663870e+06            98.1865               111.9580
# 2     2.819100e+06            95.4500                72.6428
# 3     4.317100e+05            96.9396                83.8256
# 4     6.102590e+06            91.4165               109.3940
# --------------
#
# 25.th Run:
# Tournament-Selection:
#    gen  nevals  mean_training_se  std_training_se  min_training_se  \
# 0    0     500      3.345080e+12     7.471990e+13           63.708
# 1    1     114      6.497660e+06     1.450370e+08           63.708
# 2    2     120      3.323610e+04     3.660480e+05           63.708
# 3    3     148      1.038790e+05     1.669800e+06           63.708
# 4    4     128      1.161520e+05     1.713270e+06           63.708
#
#    max_training_se  elite_testing_mse  elite_testing_err_std
# 0     1.672460e+15                NaN                    NaN
# 1     3.246380e+09            67.6813                102.813
# 2     6.220130e+06            67.6813                102.813
# 3     3.657790e+07            67.6813                102.813
# 4     3.657790e+07            67.6813                102.813
# E-Lexicase-Selection:
#    gen  nevals  mean_training_se  std_training_se  min_training_se  \
# 0    0     500      2.326370e+08     3.052150e+09         110.0580
# 1    1     113      1.161610e+05     1.004940e+06         109.9820
# 2    2     117      7.938360e+02     1.061600e+04         109.9820
# 3    3     142      1.147970e+03     1.173130e+04          96.4548
# 4    4     124      3.102300e+02     3.965970e+03          96.4548
#
#    max_training_se  elite_testing_mse  elite_testing_err_std
# 0     4.746070e+10                NaN                    NaN
# 1     1.191870e+07           114.3010               139.3810
# 2     2.192170e+05           114.3010               139.3810
# 3     2.249750e+05            97.6228                72.4912
# 4     8.885930e+04            97.6228                72.4912
# --------------
#
# 26.th Run:
# Tournament-Selection:
#    gen  nevals  mean_training_se  std_training_se  min_training_se  \
# 0    0     500       476888000.0     6.042150e+09          67.1589
# 1    1     113          185225.0     3.152510e+06          67.1589
# 2    2     112           34393.1     5.386060e+05          65.1073
# 3    3     144         7217630.0     1.486670e+08          65.1073
# 4    4     117         6766420.0     1.481320e+08          65.1073
#
#    max_training_se  elite_testing_mse  elite_testing_err_std
# 0     1.199820e+11                NaN                    NaN
# 1     6.833660e+07            70.7984               109.9670
# 2     1.197850e+07            65.6918                58.6706
# 3     3.319920e+09            65.6918                58.6706
# 4     3.315710e+09            65.6918                58.6706
# E-Lexicase-Selection:
#    gen  nevals  mean_training_se  std_training_se  min_training_se  \
# 0    0     500      1.192190e+09     1.769060e+10         108.7640
# 1    1     111      2.316990e+07     5.168180e+08         108.7640
# 2    2     109      2.399350e+07     5.359420e+08          96.7314
# 3    3     116      1.323870e+03     2.598860e+04          96.6681
# 4    4     116      1.172870e+02     8.215130e+01          93.8405
#
#    max_training_se  elite_testing_mse  elite_testing_err_std
# 0     3.250230e+11                NaN                    NaN
# 1     1.156800e+10           111.5410               132.4620
# 2     1.199600e+10            97.3462                73.5392
# 3     5.813180e+05            97.3311                73.0884
# 4     5.906860e+02            94.6021                96.0951
# --------------
#
# 27.th Run:
# Tournament-Selection:
#    gen  nevals  mean_training_se  std_training_se  min_training_se  \
# 0    0     500        24974600.0     5.270670e+08         116.7080
# 1    1     132           37752.3     5.789640e+05          85.0667
# 2    2     117       455091000.0     1.010500e+10         110.6130
# 3    3     126           78978.7     1.312300e+06         110.6130
# 4    4     134           10467.8     6.464180e+04         108.4530
#
#    max_training_se  elite_testing_mse  elite_testing_err_std
# 0     1.178340e+10                NaN                    NaN
# 1     1.204030e+07            81.9647                138.506
# 2     2.261800e+11            81.9647                138.506
# 3     2.923270e+07            81.9647                138.506
# 4     6.895440e+05            81.9647                138.506
# E-Lexicase-Selection:
#    gen  nevals  mean_training_se  std_training_se  min_training_se  \
# 0    0     500      3.709570e+07     5.662780e+08          85.0667
# 1    1     121      1.026530e+05     6.906420e+05          85.0667
# 2    2     125      6.613510e+04     7.833590e+05          85.0667
# 3    3     120      1.833440e+04     2.988430e+05          85.0667
# 4    4     127      8.445360e+09     1.886530e+11          85.0667
#
#    max_training_se  elite_testing_mse  elite_testing_err_std
# 0     1.178340e+10                NaN                    NaN
# 1     1.187110e+07            81.9647                138.506
# 2     1.262240e+07            81.9647                138.506
# 3     6.172890e+06            81.9647                138.506
# 4     4.222640e+12            81.9647                138.506
# --------------
#
# 28.th Run:
# Tournament-Selection:
#    gen  nevals  mean_training_se  std_training_se  min_training_se  \
# 0    0     500      1.379200e+08     2.238460e+09          87.3573
# 1    1     138      3.985410e+03     3.785670e+04          87.3573
# 2    2     127      2.774320e+04     5.357900e+05          87.3573
# 3    3     109      5.985010e+04     5.387760e+05          87.3573
# 4    4     114      1.314460e+05     1.050960e+06          87.3573
#
#    max_training_se  elite_testing_mse  elite_testing_err_std
# 0     4.838660e+10                NaN                    NaN
# 1     6.935380e+05            79.6741                140.934
# 2     1.192270e+07            79.6741                140.934
# 3     7.607790e+06            79.6741                140.934
# 4     1.205380e+07            79.6741                140.934
# E-Lexicase-Selection:
#    gen  nevals  mean_training_se  std_training_se  min_training_se  \
# 0    0     500      1.790080e+09     3.088910e+10          22.9098
# 1    1     135      1.158880e+08     1.140970e+09          22.9098
# 2    2     120      4.630850e+03     7.319550e+04          22.9098
# 3    3     134      1.837730e+04     1.917700e+05          22.9098
# 4    4     135      9.261380e+02     5.405300e+03          22.9098
#
#    max_training_se  elite_testing_mse  elite_testing_err_std
# 0     6.861580e+11                NaN                    NaN
# 1     1.146790e+10            24.4153                37.6132
# 2     1.577940e+06            24.4153                37.6132
# 3     3.171450e+06            24.4153                37.6132
# 4     8.201620e+04            24.4153                37.6132
# --------------
#
# 29.th Run:
# Tournament-Selection:
#    gen  nevals  mean_training_se  std_training_se  min_training_se  \
# 0    0     500      3.870150e+09     6.007360e+10          79.6671
# 1    1     122      7.605160e+03     8.576260e+04          73.2848
# 2    2     128      7.241200e+04     9.187060e+05          73.2848
# 3    3     111      1.145520e+05     1.106060e+06          36.8616
# 4    4     116      1.578050e+05     1.467060e+06          27.6328
#
#    max_training_se  elite_testing_mse  elite_testing_err_std
# 0     1.300740e+12                NaN                    NaN
# 1     1.744740e+06            82.5030               106.5530
# 2     1.654120e+07            82.5030               106.5530
# 3     1.654120e+07            36.8099                49.7641
# 4     2.689310e+07            26.0207                43.6014
# E-Lexicase-Selection:
#    gen  nevals  mean_training_se  std_training_se  min_training_se  \
# 0    0     500       187612000.0     2.373860e+09          73.7905
# 1    1     162          183464.0     1.211650e+06          73.7905
# 2    2     127           62093.2     6.458180e+05          73.7905
# 3    3     115           47258.6     7.434270e+05          73.7905
# 4    4     138       470497000.0     1.049910e+10          73.7905
#
# ...
# 3     3.412800e+09            34.7810                58.4613
# 4     6.307530e+06            34.7810                58.4613
# E-Lexicase-Selection:
#    gen  nevals  mean_training_se  std_training_se  min_training_se  \
# 0    0     500        61591200.0      886007000.0          76.2823
# 1    1     108          206469.0        1379180.0          76.2823
# 2    2     118           30233.7         354478.0          76.2823
# 3    3     113           11427.9         176287.0          76.2823
# 4    4     126          114377.0        2124810.0          19.5857
#
#    max_training_se  elite_testing_mse  elite_testing_err_std
# 0     1.587180e+10                NaN                    NaN
# 1     1.174070e+07            90.7491               148.0560
# 2     6.307530e+06            90.7491               148.0560
# 3     3.131230e+06            90.7491               148.0560
# 4     4.728140e+07            21.5935                40.7786
# --------------
#
# 92.th Run:
# Tournament-Selection:
#    gen  nevals  mean_training_se  std_training_se  min_training_se  \
# 0    0     500      1.348030e+08     2.254410e+09          80.2374
# 1    1     121      5.850440e+03     6.710460e+04          80.2374
# 2    2     100      2.249220e+04     2.862160e+05          80.2374
# 3    3     113      1.008000e+05     1.093570e+06          67.9349
# 4    4     119      4.556660e+07     1.014660e+09          27.4828
#
#    max_training_se  elite_testing_mse  elite_testing_err_std
# 0     4.889720e+10                NaN                    NaN
# 1     1.362850e+06            86.7940               138.0440
# 2     6.066460e+06            86.7940               138.0440
# 3     1.825780e+07            62.8642                57.6628
# 4     2.271130e+10            26.1707                43.9571
# E-Lexicase-Selection:
#    gen  nevals  mean_training_se  std_training_se  min_training_se  \
# 0    0     500        50452900.0     5.711050e+08          80.2374
# 1    1     129           87413.3     7.946360e+05          80.2374
# 2    2     111       507857000.0     1.134310e+10          80.2374
# 3    3     102           13605.6     2.807750e+05          80.2374
# 4    4     119           48398.2     6.392650e+05          80.2374
#
#    max_training_se  elite_testing_mse  elite_testing_err_std
# 0     8.499460e+09                NaN                    NaN
# 1     1.211130e+07             86.794                138.044
# 2     2.538940e+11             86.794                138.044
# 3     6.270690e+06             86.794                138.044
# 4     1.246460e+07             86.794                138.044
# --------------
#
# 93.th Run:
# Tournament-Selection:
#    gen  nevals  mean_training_se  std_training_se  min_training_se  \
# 0    0     500          155557.0        1013310.0          83.9759
# 1    1     141           93742.7        1549720.0          83.9759
# 2    2     129           12615.3         151579.0          83.9759
# 3    3     101           52040.5         600723.0          83.9759
# 4    4     109           78173.1         669941.0          83.9759
#
#    max_training_se  elite_testing_mse  elite_testing_err_std
# 0       15889600.0                NaN                    NaN
# 1       33753500.0            83.0555                134.638
# 2        3250250.0            83.0555                134.638
# 3       12042300.0            83.0555                134.638
# 4       12042300.0            83.0555                134.638
# E-Lexicase-Selection:
#    gen  nevals  mean_training_se  std_training_se  min_training_se  \
# 0    0     500      5.148930e+08     1.016320e+10          49.8555
# 1    1     140      1.892460e+08     1.476880e+09          49.8555
# 2    2     119      4.497010e+04     8.113380e+05          45.8156
# 3    3     118      9.378520e+03     1.502020e+05          44.6726
# 4    4     108      2.366610e+03     1.991160e+04          44.3114
#
#    max_training_se  elite_testing_mse  elite_testing_err_std
# 0     2.265540e+11                NaN                    NaN
# 1     1.178420e+10            48.0032                49.0620
# 2     1.808140e+07            44.6020                49.0691
# 3     3.305680e+06            44.2553                52.9356
# 4     3.100880e+05            44.0425                54.1122
# --------------
#
# 94.th Run:
# Tournament-Selection:
#    gen  nevals  mean_training_se  std_training_se  min_training_se  \
# 0    0     500      1.992590e+08     2.998300e+09         114.1090
# 1    1     137      1.973940e+07     4.406620e+08         114.1090
# 2    2     125      3.589080e+03     2.417290e+04          95.9304
# 3    3     114      3.260190e+04     5.469520e+05          94.3481
# 4    4     123      1.827160e+04     2.634690e+05          94.3481
#
#    max_training_se  elite_testing_mse  elite_testing_err_std
# 0     4.780490e+10                NaN                    NaN
# 1     9.863380e+09           110.3270               133.7000
# 2     4.277560e+05            93.0254                92.5892
# 3     1.209910e+07            94.1819                86.9706
# 4     5.737840e+06            94.1819                86.9706
# E-Lexicase-Selection:
#    gen  nevals  mean_training_se  std_training_se  min_training_se  \
# 0    0     500       719705000.0     1.043590e+10          86.0837
# 1    1     116          200537.0     1.420480e+06          86.0837
# 2    2     122         1564730.0     3.438970e+07          86.0837
# 3    3     153          249986.0     5.485340e+06          86.0837
# 4    4     110          213700.0     3.586330e+06          86.0837
#
#    max_training_se  elite_testing_mse  elite_testing_err_std
# 0     2.227440e+11                NaN                    NaN
# 1     1.209910e+07            80.9477                 136.96
# 2     7.697280e+08            80.9477                 136.96
# 3     1.227740e+08            80.9477                 136.96
# 4     7.829180e+07            80.9477                 136.96
# --------------
#
# 95.th Run:
# Tournament-Selection:
#    gen  nevals  mean_training_se  std_training_se  min_training_se  \
# 0    0     500       203899000.0     2.768960e+09          71.4134
# 1    1     115         6737540.0     1.497020e+08          71.4134
# 2    2     145           32128.6     3.655550e+05          71.4134
# 3    3     101           29598.4     2.746840e+05          71.4134
# 4    4     123           68930.3     7.112920e+05          71.4134
#
#    max_training_se  elite_testing_mse  elite_testing_err_std
# 0     4.802570e+10                NaN                    NaN
# 1     3.350810e+09             84.722                113.633
# 2     6.428550e+06             84.722                113.633
# 3     4.087720e+06             84.722                113.633
# 4     1.447940e+07             84.722                113.633
# E-Lexicase-Selection:
#    gen  nevals  mean_training_se  std_training_se  min_training_se  \
# 0    0     500      7.156520e+08     1.049400e+10          81.2895
# 1    1     126      1.087390e+07     2.407830e+08          81.2895
# 2    2     111      1.056520e+05     1.710720e+06          81.2895
# 3    3     121      2.036740e+05     4.541550e+06          81.2895
# 4    4     115      1.787920e+09     3.993850e+10          71.4134
#
#    max_training_se  elite_testing_mse  elite_testing_err_std
# 0     2.278160e+11                NaN                    NaN
# 1     5.389490e+09            85.7419                137.402
# 2     3.349510e+07            85.7419                137.402
# 3     1.016540e+08            85.7419                137.402
# 4     8.939470e+11            84.7220                113.633
# --------------
#
# 96.th Run:
# Tournament-Selection:
#    gen  nevals  mean_training_se  std_training_se  min_training_se  \
# 0    0     500      1.439950e+09     2.785910e+10          75.7553
# 1    1     129      2.511590e+03     2.341090e+04          26.1980
# 2    2     126      2.207010e+04     2.361650e+05          75.7553
# 3    3     121      1.723750e+05     2.598540e+06          74.1383
# 4    4     116      1.014010e+07     1.659870e+08          61.1222
#
#    max_training_se  elite_testing_mse  elite_testing_err_std
# 0     6.202740e+11                NaN                    NaN
# 1     4.312620e+05            28.9831                48.6742
# 2     4.835550e+06            28.9831                48.6742
# 3     5.579450e+07            28.9831                48.6742
# 4     3.245140e+09            28.9831                48.6742
# E-Lexicase-Selection:
#    gen  nevals  mean_training_se  std_training_se  min_training_se  \
# 0    0     500       222610000.0     2.724150e+09          79.3782
# 1    1     107          197245.0     1.924590e+06          79.3782
# 2    2     102         6528820.0     1.449610e+08          79.3782
# 3    3     123           33167.3     5.450030e+05          79.3782
# 4    4     123        21805600.0     4.864010e+08          79.3782
#
#    max_training_se  elite_testing_mse  elite_testing_err_std
# 0     4.658190e+10                NaN                    NaN
# 1     3.660540e+07            87.6532                144.361
# 2     3.244700e+09            87.6532                144.361
# 3     1.177430e+07            87.6532                144.361
# 4     1.088720e+10            87.6532                144.361
# --------------
#
# 97.th Run:
# Tournament-Selection:
#    gen  nevals  mean_training_se  std_training_se  min_training_se  \
# 0    0     500       289146000.0     2.434980e+09          57.3343
# 1    1     112        96311200.0     2.150880e+09          57.3343
# 2    2     136        96311900.0     2.150090e+09          24.3452
# 3    3     114       129845000.0     2.275020e+09          32.1995
# 4    4     128          162936.0     1.152790e+06          32.1995
#
#    max_training_se  elite_testing_mse  elite_testing_err_std
# 0     3.605280e+10                NaN                    NaN
# 1     4.814330e+10            67.5318               102.4180
# 2     4.812560e+10            26.8594                42.9858
# 3     4.812410e+10            26.8594                42.9858
# 4     1.196850e+07            26.8594                42.9858
# E-Lexicase-Selection:
#    gen  nevals  mean_training_se  std_training_se  min_training_se  \
# 0    0     500      8.865520e+07     1.137860e+09          115.615
# 1    1     105      1.482180e+05     2.082590e+06          115.615
# 2    2     119      2.780940e+06     5.714220e+07          115.615
# 3    3     130      4.223390e+04     6.270680e+05          115.615
# 4    4     106      2.069120e+02     1.511560e+03          115.615
#
#    max_training_se  elite_testing_mse  elite_testing_err_std
# 0     1.675330e+10                NaN                    NaN
# 1     4.335190e+07            108.821                134.275
# 2     1.277220e+09            108.821                134.275
# 3     1.135100e+07            108.821                134.275
# 4     3.387100e+04            108.821                134.275
# --------------
#
# 98.th Run:
# Tournament-Selection:
#    gen  nevals  mean_training_se  std_training_se  min_training_se  \
# 0    0     500      1.426280e+09     1.893810e+10         108.6230
# 1    1     118      7.369060e+03     8.952950e+04         114.6510
# 2    2     127      6.565510e+06     1.465090e+08          60.6116
# 3    3     118      4.444320e+04     4.078100e+05          60.6116
# 4    4     118      2.322770e+07     5.171260e+08          60.6116
#
#    max_training_se  elite_testing_mse  elite_testing_err_std
# 0     3.545690e+11                NaN                    NaN
# 1     1.884490e+06           105.3830                113.990
# 2     3.279330e+09            64.9419                102.028
# 3     4.946440e+06            64.9419                102.028
# 4     1.157490e+10            64.9419                102.028
# E-Lexicase-Selection:
#    gen  nevals  mean_training_se  std_training_se  min_training_se  \
# 0    0     500      6.363200e+08     1.042600e+10          114.948
# 1    1     136      2.991530e+05     1.800170e+06          113.115
# 2    2     119      1.222040e+03     1.957400e+04          112.250
# 3    3      86      1.809790e+02     1.174550e+03          110.745
# 4    4     134      1.600150e+02     6.899240e+02           96.973
#
#    max_training_se  elite_testing_mse  elite_testing_err_std
# 0     2.229100e+11                NaN                    NaN
# 1     1.950880e+07            110.311                83.7982
# 2     4.221000e+05            109.570                82.6602
# 3     2.638530e+04            105.569               128.8740
# 4     1.549670e+04             97.234                71.7608
# --------------
#
# 99.th Run:
# Tournament-Selection:
#    gen  nevals  mean_training_se  std_training_se  min_training_se  \
# 0    0     500       252068000.0     5.466960e+09          86.2254
# 1    1     124           45618.5     7.819120e+05          86.2254
# 2    2     122           35842.7     3.091370e+05          86.2254
# 3    3     136           83964.5     8.778450e+05          86.2254
# 4    4     122           55107.2     4.781170e+05          86.2254
#
#    max_training_se  elite_testing_mse  elite_testing_err_std
# 0     1.223310e+11                NaN                    NaN
# 1     1.718700e+07             80.806                130.106
# 2     4.925080e+06             80.806                130.106
# 3     1.733130e+07             80.806                130.106
# 4     8.390310e+06             80.806                130.106
# E-Lexicase-Selection:
#    gen  nevals  mean_training_se  std_training_se  min_training_se  \
# 0    0     500      1.082990e+08     2.132090e+09          111.932
# 1    1     123      6.497130e+06     1.449450e+08          111.932
# 2    2     115      3.729350e+03     4.266810e+04          111.932
# 3    3     100      1.995350e+03     2.582260e+04          111.932
# 4    4     125      4.683100e+04     9.944120e+05          111.932
#
#    max_training_se  elite_testing_mse  elite_testing_err_std
# 0     4.759280e+10                NaN                    NaN
# 1     3.244330e+09            112.504                139.187
# 2     6.937600e+05            112.504                139.187
# 3     4.228000e+05            112.504                139.187
# 4     2.224520e+07            112.504                139.187
# --------------
#
# 100.th Run:
# Tournament-Selection:
#    gen  nevals  mean_training_se  std_training_se  min_training_se  \
# 0    0     500       456609000.0     1.013510e+10          103.570
# 1    1     105           70758.2     1.371680e+06          103.570
# 2    2     127        52488300.0     1.172100e+09          103.570
# 3    3     119           84024.4     9.793310e+05           94.656
# 4    4     122           12521.0     1.793920e+05           94.656
#
#    max_training_se  elite_testing_mse  elite_testing_err_std
# 0     2.268560e+11                NaN                    NaN
# 1     3.067230e+07           106.1460               118.1360
# 2     2.623530e+10           106.1460               118.1360
# 3     1.695560e+07            94.2998                93.5548
# 4     3.758700e+06            94.2998                93.5548
# E-Lexicase-Selection:
#    gen  nevals  mean_training_se  std_training_se  min_training_se  \
# 0    0     500       460683000.0     1.013590e+10          85.1073
# 1    1     114          158158.0     1.118330e+06          85.1073
# 2    2     128          118532.0     5.464300e+05          76.4931
# 3    3     116         1054560.0     2.225520e+07          76.4931
# 4    4     111           59175.9     9.064790e+05          76.4931
#
#    max_training_se  elite_testing_mse  elite_testing_err_std
# 0     2.268550e+11                NaN                    NaN
# 1     1.187360e+07            81.9241                136.996
# 2     3.284330e+06            79.6423                109.924
# 3     4.975710e+08            79.6423                109.924
# 4     1.644550e+07            79.6423                109.924
# --------------

# %%
def to_master_record(dfs: List[pd.DataFrame]) -> pd.DataFrame:
    
    """
    Summarize and return the results from each individual dataframe into a master record
    """
    
    headers = dfs[0].columns.values.tolist()
    ngens = len(dfs[0]["gen"])
    
    master = pd.DataFrame(0, index=np.arange(ngens), columns=headers)
    
    def mean_stddev(std_devs: List[float]) -> float:
        """returns the mean for a list of std_deviations """
        agg = 0.0
        for std_dev in std_devs:
            agg += std_dev ** 2
        return sqrt(agg / len(std_devs))
    
    for header in headers:
                
        for gen in range(ngens):
            
            vals = []
            
            for df in dfs:
                vals.append(
                    float(df[header].iloc[gen])
                )

            master.loc[gen,header]
            if not "std" in header:
                master.loc[gen,header] = mean(vals)
            
            else:
                master.loc[gen,header] = mean_stddev(vals)
                
    return master



master_tournmament = to_master_record(tournament_logs)
master_elexicase = to_master_record(elexicase_logs)

# %%
master_tournmament.to_csv(path_or_buf=f"{TABLE_PATH}/csv/master_tournament.csv")
master_tournmament.to_markdown(buf=f"{TABLE_PATH}/md/master_tournament.md")

master_tournmament
# Out:
#    gen  nevals  mean_training_se  std_training_se  min_training_se  \
# 0    0   50.00      7.206743e+10     4.900325e+12       144.530728
# 1    1   12.32      5.027360e+07     3.198816e+09       135.263557
# 2    2   11.80      5.106664e+05     3.201457e+07       128.480600
# 3    3   11.38      1.146125e+07     6.829816e+08       118.798197
# 4    4   12.36      5.748104e+06     2.858449e+08       114.990169
# 5    5   12.03      4.578615e+07     3.139989e+09       111.902936
#
#    max_training_se  elite_testing_mse  elite_testing_err_std
# 0     3.601899e+12                NaN                    NaN
# 1     2.513529e+09         134.531064             165.720440
# 2     2.490615e+07         128.053816             157.283951
# 3     5.723577e+08         117.027291             142.951712
# 4     2.869118e+08         113.473410             141.286382
# 5     2.285297e+09         110.906479             136.094299

# %%
master_tournmament.describe().to_csv(path_or_buf=f"{TABLE_PATH}/csv/master_tournament_descriptive.csv")
master_tournmament.describe().to_markdown(buf=f"{TABLE_PATH}/md/master_tournament_descriptive.md")

master_tournmament.describe()
# Out:
#             gen     nevals  mean_training_se  std_training_se  \
# count  6.000000   6.000000      6.000000e+00     6.000000e+00
# mean   2.500000  18.315000      1.203020e+10     8.179441e+11
# std    1.870829  15.526635      2.941212e+10     1.999951e+12
# min    0.000000  11.380000      5.106664e+05     3.201457e+07
# 25%    1.250000  11.857500      7.176390e+06     3.851291e+08
# 50%    2.500000  12.175000      2.862370e+07     1.911485e+09
# 75%    3.750000  12.350000      4.915174e+07     3.184109e+09
# max    5.000000  50.000000      7.206743e+10     4.900325e+12
#
#        min_training_se  max_training_se  elite_testing_mse  \
# count         6.000000     6.000000e+00           5.000000
# mean        125.661031     6.012637e+11         120.798412
# std          12.700196     1.470006e+12          10.086550
# min         111.902936     2.490615e+07         110.906479
# 25%         115.942176     3.582733e+08         113.473410
# 50%         123.639398     1.428827e+09         117.027291
# 75%         133.567818     2.456471e+09         128.053816
# max         144.530728     3.601899e+12         134.531064
#
#        elite_testing_err_std
# count               5.000000
# mean              148.667356
# std                12.351948
# min               136.094299
# 25%               141.286382
# 50%               142.951712
# 75%               157.283951
# max               165.720440

# %%
master_elexicase.to_csv(path_or_buf=f"{TABLE_PATH}/csv/master_elexicase.csv")
master_elexicase.to_markdown(buf=f"{TABLE_PATH}/md/master_elexicase.md")

master_elexicase
# Out:
#    gen  nevals  mean_training_se  std__training_se  min__training_se  \
# 0    0   50.00      1.535816e+12      8.118274e+13        160.231312
# 1    1   11.76      8.611991e+06      3.232122e+08        139.814074
# 2    2   12.05      4.821770e+06      3.341364e+08        127.136589
# 3    3   11.83      2.273950e+06      1.548741e+08        124.083187
# 4    4   11.91      3.432598e+06      2.393332e+08        118.576303
# 5    5   12.12      9.497630e+06      6.634831e+08        116.390129
#
#    max_training_se  elite_testing_mse  elite_testing_err_std
# 0     7.678340e+13                NaN                    NaN
# 1     3.149322e+08         140.024299             173.735264
# 2     2.409695e+08         128.119909             155.995326
# 3     1.134748e+08         125.176740             152.825805
# 4     1.714633e+08         120.359152             148.123950
# 5     4.747238e+08         118.177356             144.859584

# %%
master_elexicase.describe().to_csv(path_or_buf=f"{TABLE_PATH}/csv/master_elexicase_descriptive.csv")
master_elexicase.describe().to_markdown(buf=f"{TABLE_PATH}/md/master_elexicase_descriptive.md")

master_elexicase.describe()
# Out:
#             gen     nevals  mean_training_se  std__training_se  \
# count  6.000000   6.000000      6.000000e+00      6.000000e+00
# mean   2.500000  18.278333      2.559741e+11      1.353074e+13
# std    1.870829  15.540957      6.269919e+11      3.314258e+13
# min    0.000000  11.760000      2.273950e+06      1.548741e+08
# 25%    1.250000  11.850000      3.779891e+06      2.603030e+08
# 50%    2.500000  11.980000      6.716880e+06      3.286743e+08
# 75%    3.750000  12.102500      9.276220e+06      5.811464e+08
# max    5.000000  50.000000      1.535816e+12      8.118274e+13
#
#        min__training_se  max_training_se  elite_testing_mse  \
# count          6.000000     6.000000e+00           5.000000
# mean         131.038599     1.279745e+13         126.371491
# std           16.508867     3.134658e+13           8.575774
# min          116.390129     1.134748e+08         118.177356
# 25%          119.953024     1.888398e+08         120.359152
# 50%          125.609888     2.779508e+08         125.176740
# 75%          136.644703     4.347759e+08         128.119909
# max          160.231312     7.678340e+13         140.024299
#
#        elite_testing_err_std
# count               5.000000
# mean              155.107986
# std                11.255862
# min               144.859584
# 25%               148.123950
# 50%               152.825805
# 75%               155.995326
# max               173.735264

# %%
def aggregate_cells(dfs: List[pd.DataFrame], header, row) -> List[float]:
    
    vals = []

    for df in dfs:
        
        vals.append(
            df[header].iloc[row]
        )
    
    return vals

LAST_ROW = len(tournament_logs[0]) - 1

# aggregate training errors for elite models in last generation
tournament_elite_training_errors = aggregate_cells(tournament_logs, "min_training_se", LAST_ROW)
elexicase_elite_training_errors = aggregate_cells(elexicase_logs, "min_training_se", LAST_ROW)

# aggregate elite model performance on testing data
tournament_elite_testing_errors = aggregate_cells(tournament_logs, "elite_testing_mse", LAST_ROW)
elexicase_elite_testing_errors = aggregate_cells(elexicase_logs, "elite_testing_mse", LAST_ROW)

# %%
# Check if data series are normal distributed at alpha=5%

def is_normal_distr(vals: List[float], alpha:float=0.05) -> bool:
    
    print("Null Hypothesis: Sample comes from a normal distribution")
    
    statistic, pval = normaltest(vals)
    
    print(f"Statistic: {statistic}\nP-Value: {pval}")
    
    if pval < alpha:
        print("The null hypothesis can be rejected")
    else:
        print("The null hypothesis cannot be rejected")
    print("----------")
        

is_normal_distr(tournament_elite_training_errors)
is_normal_distr(elexicase_elite_training_errors)
is_normal_distr(tournament_elite_testing_errors)
is_normal_distr(elexicase_elite_testing_errors)
# Out:
# Null Hypothesis: Sample comes from a normal distribution
# Statistic: 25.16665646744599
# P-Value: 3.4287039212410135e-06
# The null hypothesis can be rejected
# ----------
# Null Hypothesis: Sample comes from a normal distribution
# Statistic: 58.01615012112525
# P-Value: 2.523208102344635e-13
# The null hypothesis can be rejected
# ----------
# Null Hypothesis: Sample comes from a normal distribution
# Statistic: 29.68846549458086
# P-Value: 3.5746343945868624e-07
# The null hypothesis can be rejected
# ----------
# Null Hypothesis: Sample comes from a normal distribution
# Statistic: 57.71422868368015
# P-Value: 2.934367322710921e-13
# The null hypothesis can be rejected
# ----------

# %%
def test_mannwhitneyu(df: pd.DataFrame, xheader: str, yheader: str) -> Tuple[float,float]:
    
    ALPHA = 0.05

    statistic, pval = mannwhitneyu(x = df[xheader],y = df[yheader])
    print(f"Statistic: {statistic}\nPVal: {pval}\nPVal < ALPHA: {pval < ALPHA}")

    if pval > ALPHA:
        print(f"Results supports H0 for alpha={ALPHA}\n H0: The distribution underlying sample {xheader} is the same as the distribution underlying sample {yheader}")

    else:
        print(f"H0 can be rejected for alpha={ALPHA}\nThe distribution underlying sample {xheader} is NOT the same as the distribution underlying sample {yheader}")
    
    return statistic, pval

# %%
fit_train_square_mwu = test_mannwhitneyu(results_square, "fit_train_tournament", "fit_train_elexicase")

plt.figure()

subplot_train_squared = results_square.boxplot(column=[HEADERS[0], HEADERS[2]])
subplot_train_squared.set_ylabel("MSE")
subplot_train_squared.set_title(f"Distribution for n={n_squared} runs")

plt.savefig("../docs/rmd/plots/box_train_square.png")

# %%
fit_train_abs_mwu = test_mannwhitneyu(results_absolute, "fit_train_tournament", "fit_train_elexicase")

plt.figure()

subplot_train_absolute = results_absolute.boxplot(column=[HEADERS[0], HEADERS[2]])
subplot_train_absolute.set_ylabel("MAE")
subplot_train_absolute.set_title(f"Distribution for n={n_absolute} runs")

plt.savefig("../docs/rmd/plots/box_train_absolute.png")

# %%
fit_test_square_mwu = test_mannwhitneyu(results_square, "fit_test_tournament", "fit_test_elexicase")

plt.figure()

subplot_test_squared = results_square.boxplot(column=[HEADERS[1], HEADERS[3]])
subplot_test_squared.set_ylabel("MSE")
subplot_test_squared.set_title(f"Distribution for n={n_squared} runs")

plt.savefig("../docs/rmd/plots/box_test_square.png")

# %%
fit_test_abs_mwu = test_mannwhitneyu(results_absolute, "fit_test_tournament", "fit_test_elexicase")

plt.figure()

subplot_test_absolute = results_absolute.boxplot(column=[HEADERS[1], HEADERS[3]])
subplot_test_absolute.set_ylabel("MAE")
subplot_test_absolute.set_title(f"Distribution for n={n_absolute} runs")

plt.savefig("../docs/rmd/plots/box_test_abs.png")

# %%
# save mwu results in csv files

ALPHA = 0.05
PATH = "../docs/rmd/tables/testing_mwu.csv"

with open(PATH, "w") as file:
    file.write("phase,fitness_function,statistic,p-val,lt_alpha\n")
    file.write(f"testing,mse,{fit_test_square_mwu[0]},{fit_test_square_mwu[1]},{fit_test_square_mwu[1] < ALPHA}\n")
    file.write(f"testing,mae,{fit_test_abs_mwu[0]},{fit_test_abs_mwu[1]},{fit_test_abs_mwu[1] < ALPHA}\n")

PATH = "../docs/rmd/tables/training_mwu.csv"

with open(PATH, "w") as file:
    file.write("phase,fitness_function,statistic,p-val,lt_alpha\n")
    file.write(f"training,mse,{fit_train_square_mwu[0]},{fit_train_square_mwu[1]},{fit_train_square_mwu[1] < ALPHA}\n")
    file.write(f"training,mae,{fit_train_abs_mwu[0]},{fit_train_abs_mwu[1]},{fit_train_abs_mwu[1] < ALPHA}\n")
